# %% [markdown]
# # ERA5 All Subfolders Check
#
# This notebook scans **all** `nc_*` subfolders under `DATA_ROOT`, loads them lazily with xarray, and builds a side‑by‑side summary:
# - file counts
# - time range & length
# - spatial coverage & resolution
# - variable names
# - basic per‑variable stats (first time slice only; optional & limited for speed)
# - pairwise alignment checks (do time/lat/lon shapes match?)
#
# > Tip: If you have many files, this still stays fairly light because we use `open_mfdataset(..., combine='by_coords')` lazily.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import xarray as xr

# ------------ CONFIG -------------
# Change this to your path:
# DATA_ROOT = Path('/home/ryukomura/Desktop/WeatherForcastWithHrmAndSatSwinMAE/raw_data')
DATA_ROOT = Path('./raw_data')

# NetCDF engine. Set to None to let xarray decide automatically.
NETCDF_ENGINE = None  # 'netcdf4' or 'h5netcdf' or None

# Whether to compute quick per-variable stats on first time slice for each subfolder.
# Set to 0 to skip, or a positive integer to limit to the first N variables in that folder.
PER_VAR_STATS_LIMIT = 6  # e.g., 6; set 0 to disable
# ---------------------------------

print('DATA_ROOT =', DATA_ROOT.resolve())
# Out:
# DATA_ROOT = /home/ryukomura/Desktop/WeatherForcastWithHrmAndSatSwinMAE/dataset/raw_data

# %%
def list_nc_subdirs(root: Path):
    return sorted([p for p in root.iterdir() if p.is_dir() and p.name.startswith('nc_')])

def list_files(folder: Path, pattern='*.nc'):
    return sorted([str(p) for p in folder.glob(pattern)])

def open_mf(files, engine=None):
    if not files:
        return None
    if engine:
        return xr.open_mfdataset(files, combine='by_coords', engine=engine)
    return xr.open_mfdataset(files, combine='by_coords')

def safe_float(x):
    try:
        return float(x)
    except Exception:
        return None

# %% [markdown]
# ## Scan all subfolders and build a summary table

# %%
subs = list_nc_subdirs(DATA_ROOT)
print(f'Found {len(subs)} subfolders:', [s.name for s in subs])

rows = []
pervar_rows = []

for s in subs:
    files = list_files(s)
    rec = {
        'subdir': s.name,
        'n_files': len(files),
        'time_len': None, 'time_start': None, 'time_end': None,
        'lat_len': None, 'lon_len': None,
        'lat_min': None, 'lat_max': None,
        'lon_min': None, 'lon_max': None,
        'lat_res': None, 'lon_res': None,
        'variables': None,
        'error': None,
    }
    if not files:
        rows.append(rec)
        continue
    ds = None
    try:
        ds = open_mf(files, NETCDF_ENGINE)
        
        print("####################################################")
        print(f'Processing {s.name} with {len(files)} files...')
        print(ds)
        
        # Dims
        dims = dict(ds.dims)
        rec['time_len'] = int(dims.get('time', -1)) if 'time' in dims else None
        rec['lat_len']  = int(dims.get('latitude', dims.get('lat', -1)))
        rec['lon_len']  = int(dims.get('longitude', dims.get('lon', -1)))

        # Coords and ranges
        latn = 'latitude' if 'latitude' in ds.coords else ('lat' if 'lat' in ds.coords else None)
        lonn = 'longitude' if 'longitude' in ds.coords else ('lon' if 'lon' in ds.coords else None)

        if 'time' in ds.coords:
            tvals = ds['time'].values
            if len(tvals) > 0:
                import pandas as pd
                rec['time_start'] = pd.to_datetime(tvals[0]).to_pydatetime()
                rec['time_end']   = pd.to_datetime(tvals[-1]).to_pydatetime()

        if latn:
            lat = ds[latn].values
            rec['lat_min'] = safe_float(lat.min())
            rec['lat_max'] = safe_float(lat.max())
            if len(lat) > 1:
                rec['lat_res'] = safe_float(np.abs(lat[1] - lat[0]))

        if lonn:
            lon = ds[lonn].values
            rec['lon_min'] = safe_float(lon.min())
            rec['lon_max'] = safe_float(lon.max())
            if len(lon) > 1:
                rec['lon_res'] = safe_float(np.abs(lon[1] - lon[0]))

        # Variables
        vnames = list(ds.data_vars)
        rec['variables'] = ','.join(vnames[:12]) + ('...' if len(vnames) > 12 else '')

        # Optional quick per-variable stats (first time slice only)
        if PER_VAR_STATS_LIMIT and len(vnames) > 0:
            limit = min(PER_VAR_STATS_LIMIT, len(vnames))
            for vn in vnames[:limit]:
                try:
                    da = ds[vn]
                    if 'time' in da.dims:
                        da0 = da.isel(time=0)
                    else:
                        da0 = da
                    a = da0.values
                    pervar_rows.append({
                        'subdir': s.name, 'var': vn,
                        'min': float(np.nanmin(a)),
                        'max': float(np.nanmax(a)),
                        'mean': float(np.nanmean(a)),
                        'std': float(np.nanstd(a)),
                        'shape': str(list(a.shape)),
                        'dtype': str(a.dtype),
                    })
                except Exception as e:
                    pervar_rows.append({'subdir': s.name, 'var': vn, 'error': str(e)})
    except Exception as e:
        rec['error'] = str(e)
    finally:
        if ds is not None:
            ds.close()
    rows.append(rec)

summary_df = pd.DataFrame(rows).sort_values('subdir').reset_index(drop=True)
summary_df
# Out:
# Found 7 subfolders: ['nc_cp', 'nc_r', 'nc_sp', 'nc_ssrd', 'nc_t', 'nc_u10', 'nc_v10']
# ####################################################
# Processing nc_cp with 25 files...
# <xarray.Dataset> Size: 104MB
# Dimensions:     (valid_time: 25, latitude: 721, longitude: 1440)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 200B 2025-08-01 ... 2025-08-02
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     expver      <U4 16B '0005'
# Data variables:
#     cp          (valid_time, latitude, longitude) float32 104MB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-08-12T01:58 GRIB to CDM+CF via cfgrib-0.9.1...
# ####################################################
# Processing nc_cp with 25 files...
# <xarray.Dataset> Size: 104MB
# Dimensions:     (valid_time: 25, latitude: 721, longitude: 1440)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 200B 2025-08-01 ... 2025-08-02
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     expver      <U4 16B '0005'
# Data variables:
#     cp          (valid_time, latitude, longitude) float32 104MB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-08-12T01:58 GRIB to CDM+CF via cfgrib-0.9.1...
# /tmp/ipykernel_3287959/1555803864.py:32: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   dims = dict(ds.dims)
# ####################################################
# Processing nc_r with 25 files...
# <xarray.Dataset> Size: 623MB
# Dimensions:         (valid_time: 25, pressure_level: 6, latitude: 721,
#                      longitude: 1440)
# Coordinates:
#     number          int64 8B 0
#   * valid_time      (valid_time) datetime64[ns] 200B 2025-08-01 ... 2025-08-02
#   * pressure_level  (pressure_level) float64 48B 1e+03 850.0 ... 400.0 300.0
#   * latitude        (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude       (longitude) float64 12kB 0.0 0.25 0.5 ... 359.2 359.5 359.8
#     expver          <U4 16B '0005'
# Data variables:
#     r               (valid_time, pressure_level, latitude, longitude) float32 623MB dask.array<chunksize=(1, 3, 361, 720), meta=np.ndarray>
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-08-12T01:11 GRIB to CDM+CF via cfgrib-0.9.1...
# /tmp/ipykernel_3287959/1555803864.py:32: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   dims = dict(ds.dims)
# ####################################################
# Processing nc_sp with 25 files...
# <xarray.Dataset> Size: 104MB
# Dimensions:     (valid_time: 25, latitude: 721, longitude: 1440)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 200B 2025-08-01 ... 2025-08-02
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     expver      <U4 16B '0005'
# Data variables:
#     sp          (valid_time, latitude, longitude) float32 104MB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-08-12T01:22 GRIB to CDM+CF via cfgrib-0.9.1...
# /tmp/ipykernel_3287959/1555803864.py:32: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   dims = dict(ds.dims)
# ####################################################
# Processing nc_ssrd with 25 files...
# <xarray.Dataset> Size: 104MB
# Dimensions:     (valid_time: 25, latitude: 721, longitude: 1440)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 200B 2025-08-01 ... 2025-08-02
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     expver      <U4 16B '0005'
# Data variables:
#     ssrd        (valid_time, latitude, longitude) float32 104MB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-08-12T02:11 GRIB to CDM+CF via cfgrib-0.9.1...
# /tmp/ipykernel_3287959/1555803864.py:32: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   dims = dict(ds.dims)
# ####################################################
# Processing nc_t with 310 files...
# <xarray.Dataset> Size: 922MB
# Dimensions:         (valid_time: 37, pressure_level: 6, latitude: 721,
#                      longitude: 1440)
# Coordinates:
#     number          int64 8B 0
#   * valid_time      (valid_time) datetime64[ns] 296B 2024-08-01T12:00:00 ... ...
#   * pressure_level  (pressure_level) float64 48B 1e+03 850.0 ... 400.0 300.0
#   * latitude        (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude       (longitude) float64 12kB 0.0 0.25 0.5 ... 359.2 359.5 359.8
#     expver          (valid_time) <U4 592B '0001' '0001' '0001' ... '0005' '0005'
# Data variables:
#     t               (valid_time, pressure_level, latitude, longitude) float32 922MB dask.array<chunksize=(1, 3, 361, 720), meta=np.ndarray>
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-08-12T12:05 GRIB to CDM+CF via cfgrib-0.9.1...
# /tmp/ipykernel_3287959/1555803864.py:32: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   dims = dict(ds.dims)
# ####################################################
# Processing nc_u10 with 25 files...
# <xarray.Dataset> Size: 104MB
# Dimensions:     (valid_time: 25, latitude: 721, longitude: 1440)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 200B 2025-08-01 ... 2025-08-02
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     expver      <U4 16B '0005'
# Data variables:
#     u10         (valid_time, latitude, longitude) float32 104MB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-08-12T01:34 GRIB to CDM+CF via cfgrib-0.9.1...
# /tmp/ipykernel_3287959/1555803864.py:32: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   dims = dict(ds.dims)
# ####################################################
# Processing nc_v10 with 25 files...
# <xarray.Dataset> Size: 104MB
# Dimensions:     (valid_time: 25, latitude: 721, longitude: 1440)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 200B 2025-08-01 ... 2025-08-02
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     expver      <U4 16B '0005'
# Data variables:
#     v10         (valid_time, latitude, longitude) float32 104MB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-08-12T01:43 GRIB to CDM+CF via cfgrib-0.9.1...
# /tmp/ipykernel_3287959/1555803864.py:32: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   dims = dict(ds.dims)
#     subdir  n_files time_len time_start time_end  lat_len  lon_len  lat_min  \
# 0    nc_cp       25     None       None     None      721     1440    -90.0
# 1     nc_r       25     None       None     None      721     1440    -90.0
# 2    nc_sp       25     None       None     None      721     1440    -90.0
# 3  nc_ssrd       25     None       None     None      721     1440    -90.0
# 4     nc_t      310     None       None     None      721     1440    -90.0
# 5   nc_u10       25     None       None     None      721     1440    -90.0
# 6   nc_v10       25     None       None     None      721     1440    -90.0
#
#    lat_max  lon_min  lon_max  lat_res  lon_res variables error
# 0     90.0      0.0   359.75     0.25     0.25        cp  None
# 1     90.0      0.0   359.75     0.25     0.25         r  None
# 2     90.0      0.0   359.75     0.25     0.25        sp  None
# 3     90.0      0.0   359.75     0.25     0.25      ssrd  None
# 4     90.0      0.0   359.75     0.25     0.25         t  None
# 5     90.0      0.0   359.75     0.25     0.25       u10  None
# 6     90.0      0.0   359.75     0.25     0.25       v10  None

# %% [markdown]
# ### Optional: per-variable quick stats table (first time slice only)

# %%
import pandas as pd
if len(pervar_rows):
    pervar_df = pd.DataFrame(pervar_rows)
    # show a few rows; you can view full DataFrame in VS Code or export to CSV
    pervar_df.head(20)
else:
    print("PER_VAR_STATS_LIMIT == 0 or no variables found")

# %% [markdown]
# ## Pairwise alignment checks

# %%
# Build a pairwise table indicating whether time/lat/lon lengths match across subdirs
subs_names = list(summary_df['subdir'].values)
n = len(subs_names)
time_eq = np.full((n,n), True)
lat_eq  = np.full((n,n), True)
lon_eq  = np.full((n,n), True)

tlen = summary_df.set_index('subdir')['time_len'].to_dict()
llen = summary_df.set_index('subdir')['lat_len'].to_dict()
mlen = summary_df.set_index('subdir')['lon_len'].to_dict()

for i,a in enumerate(subs_names):
    for j,b in enumerate(subs_names):
        time_eq[i,j] = (tlen.get(a) == tlen.get(b))
        lat_eq[i,j]  = (llen.get(a) == llen.get(b))
        lon_eq[i,j]  = (mlen.get(a) == mlen.get(b))

time_eq_df = pd.DataFrame(time_eq, index=subs_names, columns=subs_names)
lat_eq_df  = pd.DataFrame(lat_eq,  index=subs_names, columns=subs_names)
lon_eq_df  = pd.DataFrame(lon_eq,  index=subs_names, columns=subs_names)

print("time length equal (True/False)")
display(time_eq_df)
print("lat length equal (True/False)")
display(lat_eq_df)
print("lon length equal (True/False)")
display(lon_eq_df)
# Out:
# time length equal (True/False)
#          nc_cp  nc_r  nc_sp  nc_ssrd  nc_t  nc_u10  nc_v10
# nc_cp     True  True   True     True  True    True    True
# nc_r      True  True   True     True  True    True    True
# nc_sp     True  True   True     True  True    True    True
# nc_ssrd   True  True   True     True  True    True    True
# nc_t      True  True   True     True  True    True    True
# nc_u10    True  True   True     True  True    True    True
# nc_v10    True  True   True     True  True    True    True
# lat length equal (True/False)
#          nc_cp  nc_r  nc_sp  nc_ssrd  nc_t  nc_u10  nc_v10
# nc_cp     True  True   True     True  True    True    True
# nc_r      True  True   True     True  True    True    True
# nc_sp     True  True   True     True  True    True    True
# nc_ssrd   True  True   True     True  True    True    True
# nc_t      True  True   True     True  True    True    True
# nc_u10    True  True   True     True  True    True    True
# nc_v10    True  True   True     True  True    True    True
# lon length equal (True/False)
#          nc_cp  nc_r  nc_sp  nc_ssrd  nc_t  nc_u10  nc_v10
# nc_cp     True  True   True     True  True    True    True
# nc_r      True  True   True     True  True    True    True
# nc_sp     True  True   True     True  True    True    True
# nc_ssrd   True  True   True     True  True    True    True
# nc_t      True  True   True     True  True    True    True
# nc_u10    True  True   True     True  True    True    True
# nc_v10    True  True   True     True  True    True    True

# %%
# Print all variable names for each file in every subfolder
import xarray as xr

for s in subs:
    files = list_files(s)
    print(f"\nSubfolder: {s.name}")
    for f in files:
        try:
            ds = xr.open_dataset(f, engine=NETCDF_ENGINE)
            vnames = list(ds.data_vars)
            print(f"  File: {f}")
            print(f"    Variables: {vnames}")
            ds.close()
        except Exception as e:
            print(f"  File: {f}")
            print(f"    Error: {e}")
# Out:
# Subfolder: nc_cp
#   File: raw_data/nc_cp/ERA5_2025-08-01T00_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T01_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T02_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T03_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T04_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T05_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T06_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T07_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T08_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T09_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T10_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T11_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T12_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T13_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T14_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T15_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T16_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T17_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T18_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T19_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T20_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T21_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T22_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-01T23_00_00_cp.nc
#     Variables: ['cp']
#   File: raw_data/nc_cp/ERA5_2025-08-02T00_00_00_cp.nc
#     Variables: ['cp']
#
# Subfolder: nc_r
#   File: raw_data/nc_r/ERA5_2025-08-01T00_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T01_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T02_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T03_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T04_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T05_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T06_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T07_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T08_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T09_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T10_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T11_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T12_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T13_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T14_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T15_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T16_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T17_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T18_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T19_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T20_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T21_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T22_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-01T23_00_00_r.nc
#     Variables: ['r']
#   File: raw_data/nc_r/ERA5_2025-08-02T00_00_00_r.nc
#     Variables: ['r']
#
# Subfolder: nc_sp
#   File: raw_data/nc_sp/ERA5_2025-08-01T00_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T01_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T02_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T03_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T04_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T05_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T06_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T07_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T08_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T09_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T10_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T11_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T12_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T13_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T14_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T15_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T16_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T17_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T18_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T19_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T20_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T21_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T22_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-01T23_00_00_sp.nc
#     Variables: ['sp']
#   File: raw_data/nc_sp/ERA5_2025-08-02T00_00_00_sp.nc
#     Variables: ['sp']
#
# Subfolder: nc_ssrd
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T00_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T01_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T02_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T03_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T04_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T05_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T06_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T07_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T08_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T09_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T10_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T11_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T12_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T13_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T14_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T15_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T16_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T17_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T18_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T19_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T20_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T21_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T22_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-01T23_00_00_ssrd.nc
#     Variables: ['ssrd']
#   File: raw_data/nc_ssrd/ERA5_2025-08-02T00_00_00_ssrd.nc
#     Variables: ['ssrd']
#
# Subfolder: nc_t
#   File: raw_data/nc_t/ERA5_2024-08-01T00_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T01_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T02_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T03_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T04_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T05_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T06_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T07_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T08_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T09_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T10_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T11_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T12_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T13_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T14_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T15_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T16_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T17_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T18_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T19_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T20_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T21_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T22_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-01T23_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T00_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T01_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T02_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T03_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T04_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T05_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T06_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T07_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T08_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T09_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T10_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T11_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T12_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T13_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T14_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T15_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T16_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T17_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T18_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T19_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T20_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T21_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T22_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-02T23_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T00_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T01_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T02_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T03_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T04_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T05_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T06_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T07_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T08_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T09_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T10_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T11_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T12_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T13_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T14_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T15_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T16_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T17_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T18_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T19_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T20_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T21_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T22_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-03T23_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T00_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T01_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T02_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T03_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T04_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T05_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T06_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T07_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T08_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T09_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T10_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T11_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T12_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T13_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T14_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T15_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T16_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T17_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T18_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T19_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T20_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T21_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T22_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-04T23_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T00_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T01_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T02_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T03_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T04_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T05_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T06_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T07_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T08_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T09_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T10_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T11_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T12_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T13_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T14_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T15_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T16_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T17_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T18_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T19_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T20_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T21_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T22_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-05T23_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T00_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T01_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T02_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T03_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T04_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T05_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T06_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T07_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T08_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T09_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T10_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T11_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T12_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T13_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T14_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T15_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T16_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T17_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T18_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T19_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T20_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T21_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T22_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-06T23_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T00_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T01_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T02_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T03_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T04_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T05_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T06_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T07_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T08_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T09_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T10_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T11_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T12_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T13_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T14_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T15_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T16_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T17_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T18_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T19_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T20_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T21_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T22_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-07T23_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T00_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T01_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T02_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T03_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T04_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T05_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T06_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T07_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T08_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T09_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T10_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T11_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T12_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T13_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T14_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T15_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T16_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T17_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T18_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T19_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T20_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T21_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T22_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-08T23_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T00_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T01_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T02_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T03_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T04_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T05_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T06_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T07_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T08_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T09_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T10_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T11_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T12_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T13_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T14_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T15_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T16_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T17_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T18_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T19_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T20_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T21_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T22_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-09T23_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T00_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T01_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T02_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T03_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T04_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T05_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T06_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T07_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T08_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T09_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T10_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T11_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T12_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T13_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T14_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T15_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T16_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T17_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T18_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T19_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T20_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T21_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T22_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-10T23_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T00_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T01_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T02_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T03_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T04_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T05_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T06_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T07_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T08_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T09_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T10_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T11_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T12_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T13_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T14_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T15_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T16_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T17_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T18_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T19_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T20_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T21_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T22_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-11T23_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T00_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T01_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T02_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T03_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T04_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T05_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T06_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T07_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T08_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T09_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T10_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T11_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T12_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T13_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T14_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T15_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T16_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T17_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T18_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T19_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T20_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2024-08-12T21_00_00_t.nc
#     Error: [Errno -101] NetCDF: HDF error: '/home/ryukomura/Desktop/WeatherForcastWithHrmAndSatSwinMAE/dataset/raw_data/nc_t/ERA5_2024-08-12T21_00_00_t.nc'
#   File: raw_data/nc_t/ERA5_2025-08-01T00_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T01_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T02_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T03_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T04_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T05_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T06_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T07_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T08_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T09_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T10_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T11_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T12_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T13_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T14_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T15_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T16_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T17_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T18_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T19_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T20_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T21_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T22_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-01T23_00_00_t.nc
#     Variables: ['t']
#   File: raw_data/nc_t/ERA5_2025-08-02T00_00_00_t.nc
#     Variables: ['t']
#
# Subfolder: nc_u10
#   File: raw_data/nc_u10/ERA5_2025-08-01T00_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T01_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T02_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T03_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T04_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T05_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T06_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T07_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T08_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T09_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T10_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T11_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T12_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T13_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T14_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T15_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T16_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T17_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T18_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T19_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T20_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T21_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T22_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-01T23_00_00_u10.nc
#     Variables: ['u10']
#   File: raw_data/nc_u10/ERA5_2025-08-02T00_00_00_u10.nc
#     Variables: ['u10']
#
# Subfolder: nc_v10
#   File: raw_data/nc_v10/ERA5_2025-08-01T00_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T01_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T02_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T03_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T04_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T05_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T06_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T07_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T08_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T09_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T10_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T11_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T12_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T13_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T14_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T15_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T16_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T17_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T18_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T19_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T20_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T21_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T22_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-01T23_00_00_v10.nc
#     Variables: ['v10']
#   File: raw_data/nc_v10/ERA5_2025-08-02T00_00_00_v10.nc
#     Variables: ['v10']
